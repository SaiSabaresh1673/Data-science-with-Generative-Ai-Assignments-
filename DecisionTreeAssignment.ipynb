# %% [markdown]
# ==================== DECISION TREE ASSIGNMENT ====================
#
# Question 1: What is a Decision Tree, and how does it work in the context of classification?
#
# A Decision Tree is a supervised machine learning algorithm used for classification
# and regression tasks. It works like a flowchart structure where:
#
# - Root Node → Starting decision point
# - Internal Nodes → Feature-based decisions
# - Branches → Outcome of decisions
# - Leaf Nodes → Final predicted class
#
# Working (Classification):
# 1. The algorithm selects the best feature to split the dataset.
# 2. Data is divided into subsets based on feature values.
# 3. The process repeats recursively.
# 4. Final leaf node assigns a class label.
#
# Example:
# If predicting whether email is spam or not,
# the tree may split using keywords → links → sender → attachments.
#
#
# ------------------------------------------------------------------
#
# Question 2: Explain the concepts of Gini Impurity and Entropy as impurity measures.
# How do they impact the splits in a Decision Tree?
#
# Both measure how mixed the classes are in a node.
#
# 1. Gini Impurity
#
# Formula:
# Gini = 1 − Σ(Pi²)
#
# Where Pi is probability of class i.
#
# Properties:
# - Faster to compute
# - Used in CART algorithm
# - Lower Gini = better split (more pure node)
#
# 2. Entropy
#
# Formula:
# Entropy = − Σ Pi log2(Pi)
#
# Properties:
# - Based on information theory
# - Used in ID3 algorithm
# - Lower entropy = better split
#
# Impact on Splits:
# The algorithm selects the feature that reduces impurity the most.
# Lower impurity after split → better decision boundary.
#
# Note:
# Gini is computationally faster, Entropy is more precise but slower.
#
#
# ------------------------------------------------------------------
#
# Question 3: What is the difference between Pre-Pruning and Post-Pruning in Decision Trees?
# Give one practical advantage of using each.
#
# Pre-Pruning (Early Stopping):
# Stops tree growth before it becomes too complex.
#
# Examples:
# - max_depth
# - min_samples_split
# - min_samples_leaf
#
# Advantage:
# Prevents overfitting and reduces training time.
#
# Post-Pruning (Backward Pruning):
# First grows full tree, then removes unnecessary branches.
#
# Advantage:
# Produces more accurate and generalized model than pre-pruning.
#
#
# ------------------------------------------------------------------
#
# Question 4: What is Information Gain in Decision Trees, and why is it important for choosing the best split?
#
# Information Gain measures how much uncertainty is reduced after a split.
#
# Formula:
# Information Gain = Entropy(parent) − Weighted Entropy(children)
#
# Importance:
# - Helps choose the best feature for splitting
# - Higher information gain = better feature
# - Creates more homogeneous child nodes
#
# The feature with highest information gain becomes the decision node.
#
#
# ------------------------------------------------------------------
#
# Question 5: What are some common real-world applications of Decision Trees,
# and what are their main advantages and limitations?
#
# Applications:
# 1. Medical diagnosis (disease prediction)
# 2. Loan approval systems
# 3. Customer churn prediction
# 4. Fraud detection
# 5. Email spam classification
#
# Advantages:
# - Easy to understand and interpret
# - Handles numerical and categorical data
# - Requires little data preprocessing
# - Works well with nonlinear relationships
#
# Limitations:
# - Overfitting problem
# - Sensitive to small data changes
# - Can become very large and complex
# - Lower accuracy compared to ensemble models (Random Forest)
#
# ==================================================================

# %%
#Question 6: Load Iris dataset, train Decision Tree (Gini), print accuracy and feature importance

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Load dataset
iris = load_iris()
X = iris.data
y = iris.target

# Train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train Decision Tree using Gini
model = DecisionTreeClassifier(criterion="gini", random_state=42)
model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_test)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Feature Importance
print("\nFeature Importances:")
for name, importance in zip(iris.feature_names, model.feature_importances_):
    print(name, ":", importance)
# Out:
# Accuracy: 1.0
#
# Feature Importances:
# sepal length (cm) : 0.0
# sepal width (cm) : 0.01911001911001911
# petal length (cm) : 0.8932635518001373
# petal width (cm) : 0.08762642908984374

# %%
#Question 7: Train Decision Tree with max_depth=3 and compare with full tree

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Load dataset
iris = load_iris()
X = iris.data
y = iris.target

# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Fully grown tree
full_tree = DecisionTreeClassifier(random_state=42)
full_tree.fit(X_train, y_train)
full_pred = full_tree.predict(X_test)
full_accuracy = accuracy_score(y_test, full_pred)

# Pruned tree (max_depth = 3)
pruned_tree = DecisionTreeClassifier(max_depth=3, random_state=42)
pruned_tree.fit(X_train, y_train)
pruned_pred = pruned_tree.predict(X_test)
pruned_accuracy = accuracy_score(y_test, pruned_pred)

print("Full Tree Accuracy:", full_accuracy)
print("Max Depth=3 Tree Accuracy:", pruned_accuracy)
# Out:
# Full Tree Accuracy: 1.0
# Max Depth=3 Tree Accuracy: 1.0

# %%
#Write a Python program to:
#● Load the Boston Housing Dataset
#● Train a Decision Tree Regressor
#● Print the Mean Squared Error (MSE) and feature importances

import pandas as pd
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

# Load Boston Housing dataset (modern sklearn method)
boston = fetch_openml(name="boston", version=1, as_frame=True)

X = boston.data
y = boston.target.astype(float)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train Decision Tree Regressor
model = DecisionTreeRegressor(random_state=42)
model.fit(X_train, y_train)

# Prediction
y_pred = model.predict(X_test)

# MSE
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)

# Feature Importance
print("\nFeature Importances:")
for name, importance in zip(X.columns, model.feature_importances_):
    print(name, ":", importance)
# Out:
# Mean Squared Error: 11.588026315789474
#
# Feature Importances:
# CRIM : 0.05846545229060361
# ZN : 0.000988919249451643
# INDUS : 0.009872448809169472
# CHAS : 0.0002973342835618114
# NOX : 0.007050562083191356
# RM : 0.575807411273885
# AGE : 0.007170198655228184
# DIS : 0.10962404854314393
# RAD : 0.001646356693641641
# TAX : 0.002181112508453187
# PTRATIO : 0.025042865841170155
# B : 0.011872990423277916
# LSTAT : 0.189980299345222

# %%
#Write a Python program to:
#● Load the Iris Dataset
#● Tune max_depth and min_samples_split using GridSearchCV
#● Print best parameters and accuracy

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Load dataset
iris = load_iris()
X = iris.data
y = iris.target

# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Model
dt = DecisionTreeClassifier(random_state=42)

# Hyperparameter grid
param_grid = {
    "max_depth": [2, 3, 4, 5, None],
    "min_samples_split": [2, 5, 10]
}

# Grid Search
grid = GridSearchCV(dt, param_grid, cv=5)
grid.fit(X_train, y_train)

# Best model
best_model = grid.best_estimator_
y_pred = best_model.predict(X_test)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)

print("Best Parameters:", grid.best_params_)
print("Model Accuracy:", accuracy)
# Out:
# Best Parameters: {'max_depth': 4, 'min_samples_split': 10}
# Model Accuracy: 1.0

# %% [markdown]
# ==================== QUESTION 10 ====================
#
# Healthcare Disease Prediction – Step-by-Step Process
#
# 1. Handling Missing Values
# - Identify missing data using isnull()
# - Numerical columns → fill using mean/median
# - Categorical columns → fill using mode
# - If many values missing → drop column
# - Advanced: use KNN Imputer or Iterative Imputer
#
# 2. Encoding Categorical Features
# - Binary categories → Label Encoding
# - Multiple categories → One-Hot Encoding
# - Ordinal data → Ordinal Encoding
#
# 3. Train Decision Tree Model
# - Split data into train and test sets
# - Fit DecisionTreeClassifier
# - Handle mixed data automatically (tree models support both types)
#
# 4. Hyperparameter Tuning
# Use GridSearchCV:
# - max_depth
# - min_samples_split
# - min_samples_leaf
# - criterion (gini/entropy)
#
# Select parameters giving best cross-validation score.
#
# 5. Evaluate Performance
# Use classification metrics:
# - Accuracy
# - Precision
# - Recall
# - F1 Score
# - Confusion Matrix
# - ROC-AUC curve
#
# In healthcare, Recall is most important
# (because missing a sick patient is dangerous)
#
# ------------------------------------------------------
#
# Business Value in Real World
#
# 1. Early disease detection
# 2. Reduce hospital costs
# 3. Assist doctors in diagnosis
# 4. Prioritize high-risk patients
# 5. Improve treatment planning
# 6. Save lives by faster intervention
#
# Example:
# Predict diabetes or heart disease risk from patient data.
# Hospital can alert doctors before condition becomes severe.
#
# ======================================================
